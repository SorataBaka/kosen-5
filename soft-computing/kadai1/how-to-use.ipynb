# %% [markdown]
# プログラミング課題に入る前に，Jupyter Notebookの使い方を簡単に説明します．
#
# Jupyter Notebook（ジュピターノートブックまたはジュパイターノートブック）とは，web上でプログラムを書いて，その場で実行できるwebアプリケーションです．
#
# しかも，書いたプログラムや実行結果をそのままNotebookとして保存ができます．

# %% [markdown]
# というわけで，まずは，このNotebook上で，実際にPythonのプログラムを動かしてみましょう．

# %%
# https://docs.python.org/ja/3/tutorial/interpreter.html より

the_world_is_flat = True
if the_world_is_flat:
    print("Be careful not to fall off!")
    
# エディタでプログラムを書くように，もちろんコメントも書けます
# pythonでコメントアウトしたいときは，コメントにしたい行の先頭に#をつけます．

# この，プログラムが書かれているボックスのことを「セル」と呼びます．
# プログラムを実行するには，プログラムが書かれているセルをクリックして，Shiftを押しながらEnterです．
# Out:
# Be careful not to fall off!

# %% [markdown]
# Shiftを押しながらEnterを押すと，実行した結果が，セルの下に表示されたと思います．

# %% [markdown]
# もうひとつ，実行してみましょう．
#
# `
# no = 'あなたの出席番号'
# name = 'あなたの名前'
# `
# に，自分の出席番号と名前を入れて，実行してみてください．

# %%
no = "21"
name = 'クリスティアン　ハルジュノ'

print('わたしは出席番号 ' + no + ' 番の ' + name + 'です')
# Out:
# わたしは出席番号 21 番の クリスティアン　ハルジュノです

# %% [markdown]
# Jupyterサーバに必要なライブラリがインストールしてあれば，グラフを描画することもできます．
#
# 次のセルを選択して，実行してみてください．
# グラフが表示されない場合は，再度実行してみるとよいです．

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

data = np.arange(10)

plt.plot(data)

# %% [markdown]
# 上記の例ではシンプルなグラフを描画しましたが，他にも，散布図や棒グラフなども描画できます．
#
# さらに，軸のラベルを表示したり，凡例を加えることもできます．

# %% [markdown]
# このNotebookを保存するには，左上の保存ボタンか，File→Save and Checkpointをクリックしてください．

# %% [markdown]
# プログラムを実行したときに無限ループになってしまったり，Jupyterからの反応がないときには，上のメニューから`Kernel`を選び，`Interrupt`をクリックするとプログラムを強制的に止めることができます．
#
# また，明らかにおかしい結果が出るときには，`Kernel`で`Restart`してから，実行しなおすとよいです．

# %% [markdown]
# Jupyter Notebook については，インターネット上にもたくさん情報があります．
#
# [Jupyter Notebook (調べたいこと)]というようにキーワード検索するとよいでしょう．

# %% [markdown]
# Jupyter上で新しいNotebookを作るには，右上にある New ボタンをクリックします．
#
# このとき，使える言語のリストが出てきますので，使いたい言語を選びます．
# （このNotebookを作るときには，Python 3を選びました）
#
# すると，何も書かれていないNotebookが新しいウィンドウ（またはタブ）で開きます．
#
# 新しく作ったNotebookにプログラムを書いて，実行していく，ということになります．

# %% [markdown]
# Notebookを閉じるときには，保存してから，File → Close and Halt をクリックしてください．
#
# そうすると，このタブを閉じて，Notebookの一覧ページ（ログイン後のページ）に戻ります．
