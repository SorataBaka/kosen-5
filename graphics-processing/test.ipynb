# %%
import pandas as pd
df = pd.read_csv('timelog.csv')

len(df)
# Out:
# 592

# %%
df.groupby("method")["time_sec"].agg(["mean", "std", "min", "max"]).sort_values("mean")
# Out:
#                  mean       std       min       max
# method
# Fast Oval    0.009074  0.001892  0.001104  0.011711
# Fast Circle  0.009591  0.002242  0.001776  0.016731
# Slow Circle  0.011928  0.004041  0.001165  0.026140
# Slow Oval    0.012101  0.002324  0.003359  0.018533
